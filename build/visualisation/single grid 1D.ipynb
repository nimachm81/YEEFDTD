# %%
## read left and right grids

# %pylab inline
import numpy as np
from matplotlib import pyplot as plt

from ReadBinary import *

Ex = GetArrays("../data/1D/E-x.data")[:,0,0,:]

shape = Ex.shape
print("shape : ", shape)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# shape :  (200, 801)

# %%
# %pylab tk
import numpy as np
from matplotlib import pyplot as plt
from ReadBinary import *


plt.ion()
plt.figure(figsize=(8, 6))

for n in range(Ex.shape[0]):
    plt.clf()
    plt.plot(Ex[n, :])
    plt.pause(0.01)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/nima/.local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['shape']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# %pylab inline 

plt.imshow(np.real(Ex), cmap="rainbow", origin='lower', aspect='auto')
plt.show()

Nt, Nz = Ex.shape
N_pt = 50
Ex_f = np.fft.fftshift(np.fft.fft2(Ex))[Nt//2-N_pt:Nt//2+N_pt, Nz//2-N_pt:Nz//2+N_pt]
plt.imshow(np.abs(Ex_f), cmap="rainbow", origin='lower', aspect='auto')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
